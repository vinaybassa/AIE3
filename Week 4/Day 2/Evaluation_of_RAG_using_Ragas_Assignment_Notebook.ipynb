# %% [markdown]
# # Evaluation of RAG Using Ragas
#
# In the following notebook we'll explore how to evaluate RAG pipelines using a powerful open-source tool called "Ragas". This will give us tools to evaluate component-wise metrics, as well as end-to-end metrics about the performance of our RAG pipelines.
#
# In the following notebook we'll complete the following tasks:
#
# - 🤝 Breakout Room Part #1:
#   1. Install required libraries
#   2. Set Environment Variables
#   3. Creating a simple RAG pipeline with [LangChain v0.2.0](https://python.langchain.com/v0.2/docs/versions/v0_2/)
#   4. Synthetic Dataset Generation for Evaluation using the [Ragas](https://github.com/explodinggradients/ragas) framework.
#
#
# - 🤝 Breakout Room Part #2:
#   1. Evaluating our pipeline with Ragas
#   3. Making Adjustments to our RAG Pipeline
#   4. Evaluating our Adjusted pipeline against our baseline
#   5. Testing OpenAI's Claim
#
# The only way to get started is to get started - so let's grab our dependencies for the day!
#
# > NOTE: Using this notebook as presented will occur a charge of ~$3USD from OpenAI usage. Most of this cost is produced by the Synthetic Data Generation step - if you want to reduce costs, please use the provided commented code to leverage `GPT-3.5-Turbo` as the `critic_llm`!

# %% [markdown]
# ## Motivation
#
# A claim, made by OpenAI, is that their `text-embedding-3-small` is better (generally) than their `text-embedding-ada-002` model.
#
# Here's some passages from their [blog](https://openai.com/blog/new-embedding-models-and-api-updates) about the `text-embedding-3` release:
#
# > `text-embedding-3-small` is our new highly efficient embedding model and provides a significant upgrade over its predecessor, the `text-embedding-ada-002` model...
#
# > **Stronger performance.** Comparing `text-embedding-ada-002` to `text-embedding-3-small`, the average score on a commonly used benchmark for multi-language retrieval ([MIRACL](https://github.com/project-miracl/miracl)) has increased from 31.4% to 44.0%, while the average score on a commonly used benchmark for English tasks ([MTEB](https://github.com/embeddings-benchmark/mteb)) has increased from 61.0% to 62.3%.
#
# Well, with a library like Ragas - we can put that claim to the test!
#
# If what they claim is true - we should see an increase on related metrics by using the new embedding model!

# %% [markdown]
# # 🤝 Breakout Room Part #1

# %% [markdown]
# ## Task 1: Installing Required Libraries
#
# A reminder that one of the [key features](https://blog.langchain.dev/langchain-v0-1-0/) of LangChain v0.1.0 is the compartmentalization of the various LangChain ecosystem packages!
#
# So let's begin grabbing all of our LangChain related packages!

# %%
# !pip install -U -q langchain langchain-openai langchain_core langchain-community langchainhub openai

# %% [markdown]
# We'll also get the "star of the show" today, which is Ragas!

# %%
# !pip install -qU ragas

# %% [markdown]
# We'll be leveraging [QDrant](https://qdrant.tech/) again as our LangChain `VectorStore`.
#
# We'll also install `pymupdf` and its dependencies which will allow us to load PDFs using the `PyMuPDFLoader` in the `langchain-community` package!

# %%
# !pip install -qU qdrant-client pymupdf pandas

# %% [markdown]
# ## Task 2: Set Environment Variables
#
# Let's set up our OpenAI API key so we can leverage their API later on.

# %%
import os
import openai
from getpass import getpass

openai.api_key = getpass("Please provide your OpenAI Key: ")
os.environ["OPENAI_API_KEY"] = openai.api_key

# %% [markdown]
# ## Task 3: Creating a Simple RAG Pipeline with LangChain v0.1.0
#
# Building on what we learned last week, we'll be leveraging LangChain v0.1.0 and LCEL to build a simple RAG pipeline that we can baseline with Ragas.

# %% [markdown]
# ## Building our RAG pipeline
#
# Let's review the basic steps of RAG again:
#
# - Create an Index
# - Use retrieval to obtain pieces of context from our Index that are similar to our query
# - Use a LLM to generate responses based on the retrieved context
#
# Let's get started by creating our index.
#
# > NOTE: We're going to start leaning on the term "index" to refer to our `VectorStore`, `VectorDatabase`, etc. We can think of "index" as the catch-all term, whereas `VectorStore` and the like relate to the specific technologies used to create, store, and interact with the index.

# %% [markdown]
# ### Creating an Index
#
# You'll notice that the largest changes (outside of some import changes) are that our old favourite chains are back to being bundled in an easily usable abstraction.
#
# We can still create custom chains using LCEL - but we can also be more confident that our pre-packaged chains are creating using LCEL under the hood.

# %% [markdown]
# #### Loading Data
#
# Let's start by loading some data!
#
# > NOTE: You'll notice that we're using a document loader from the community package of LangChain. This is part of the v0.2.0 changes that make the base (`langchain-core`) package remain lightweight while still providing access to some of the more powerful community integrations.

# %%
from langchain_community.document_loaders import PyMuPDFLoader

loader = PyMuPDFLoader(
    "https://d1lamhf6l6yk6d.cloudfront.net/uploads/2021/08/The-pmarca-Blog-Archives.pdf",
)

documents = loader.load()

# %%
documents[0].metadata
# Out:
# {'source': 'https://d1lamhf6l6yk6d.cloudfront.net/uploads/2021/08/The-pmarca-Blog-Archives.pdf',
#  'file_path': 'https://d1lamhf6l6yk6d.cloudfront.net/uploads/2021/08/The-pmarca-Blog-Archives.pdf',
#  'page': 0,
#  'total_pages': 195,
#  'format': 'PDF 1.3',
#  'title': 'The Pmarca Blog Archives',
#  'author': '',
#  'subject': '',
#  'keywords': '',
#  'creator': '',
#  'producer': 'Mac OS X 10.10 Quartz PDFContext',
#  'creationDate': "D:20150110020418Z00'00'",
#  'modDate': "D:20150110020418Z00'00'",
#  'trapped': ''}

# %% [markdown]
# #### Transforming Data
#
# Now that we've got our single document - let's split it into smaller pieces so we can more effectively leverage it with our retrieval chain!
#
# We'll start with the classic: `RecursiveCharacterTextSplitter`.

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size = 200,
    chunk_overlap = 50
)

documents = text_splitter.split_documents(documents)

# %% [markdown]
# Let's confirm we've split our document.

# %%
len(documents)
# Out:
# 1864

# %% [markdown]
# #### Loading OpenAI Embeddings Model
#
# We'll need a process by which we can convert our text into vectors that allow us to compare to our query vector.
#
# Let's use OpenAI's `text-embedding-ada-002` for this task!

# %%
from langchain_openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings(
    model="text-embedding-ada-002"
)

# %% [markdown]
# #### Creating a QDrant VectorStore
#
# Now that we have documents - we'll need a place to store them alongside their embeddings.

# %%
from langchain_community.vectorstores import Qdrant

qdrant_vector_store = Qdrant.from_documents(
    documents,
    embeddings,
    location=":memory:",
    collection_name="PMarca Blogs",
)

# %% [markdown]
# ####❓ Question #1:
#
# List out a few of the techniques that Qdrant uses that make it performant.
#
# Hierarchical navigable small world
# Product quantization
# Support for various metrics in distance
#
#
# > NOTE: Check the [documentation](https://qdrant.tech/documentation/overview/) for more information about QDrant!

# %% [markdown]
# #### Creating a Retriever
#
# To complete our index, all that's left to do is expose our vectorstore as a retriever - which we can do the same way we would in previous version of LangChain!

# %%
retriever = qdrant_vector_store.as_retriever()

# %% [markdown]
# #### Testing our Retriever
#
# Now that we've gone through the trouble of creating our retriever - let's see it in action!

# %%
retrieved_documents = retriever.invoke("What is a rule of thumb for selecting an industry to invest in?")

# %%
for doc in retrieved_documents:
  print(doc)
# Out:
# page_content='the existing order — and make sure that those forces of change\nhave a reasonable chance at succeeding.\nSecond rule of thumb:\nOnce you have picked an industry, get right to the center of it' metadata={'source': 'https://d1lamhf6l6yk6d.cloudfront.net/uploads/2021/08/The-pmarca-Blog-Archives.pdf', 'file_path': 'https://d1lamhf6l6yk6d.cloudfront.net/uploads/2021/08/The-pmarca-Blog-Archives.pdf', 'page': 125, 'total_pages': 195, 'format': 'PDF 1.3', 'title': 'The Pmarca Blog Archives', 'author': '', 'subject': '', 'keywords': '', 'creator': '', 'producer': 'Mac OS X 10.10 Quartz PDFContext', 'creationDate': "D:20150110020418Z00'00'", 'modDate': "D:20150110020418Z00'00'", 'trapped': '', '_id': '6f0df7afbf0b46289d184ac376b77f3b', '_collection_name': 'PMarca Blogs'}
# page_content='Third rule:\nIn a rapidly changing Held like technology, the best place to\nget experience when you’re starting out is in younger, high-\ngrowth companies.' metadata={'source': 'https://d1lamhf6l6yk6d.cloudfront.net/uploads/2021/08/The-pmarca-Blog-Archives.pdf', 'file_path': 'https://d1lamhf6l6yk6d.cloudfront.net/uploads/2021/08/The-pmarca-Blog-Archives.pdf', 'page': 127, 'total_pages': 195, 'format': 'PDF 1.3', 'title': 'The Pmarca Blog Archives', 'author': '', 'subject': '', 'keywords': '', 'creator': '', 'producer': 'Mac OS X 10.10 Quartz PDFContext', 'creationDate': "D:20150110020418Z00'00'", 'modDate': "D:20150110020418Z00'00'", 'trapped': '', '_id': 'd4b86ad778fb48ea926842e2e3773852', '_collection_name': 'PMarca Blogs'}
# page_content='where the great opportunities can be found.\nApply this rule when selecting which company to go to. Go to\nthe company where all the action is happening.' metadata={'source': 'https://d1lamhf6l6yk6d.cloudfront.net/uploads/2021/08/The-pmarca-Blog-Archives.pdf', 'file_path': 'https://d1lamhf6l6yk6d.cloudfront.net/uploads/2021/08/The-pmarca-Blog-Archives.pdf', 'page': 125, 'total_pages': 195, 'format': 'PDF 1.3', 'title': 'The Pmarca Blog Archives', 'author': '', 'subject': '', 'keywords': '', 'creator': '', 'producer': 'Mac OS X 10.10 Quartz PDFContext', 'creationDate': "D:20150110020418Z00'00'", 'modDate': "D:20150110020418Z00'00'", 'trapped': '', '_id': '6aa1c2a1163a4d43b3a882411160bc2e', '_collection_name': 'PMarca Blogs'}
# page_content='growth companies.\n(This is not necessarily true in older and more established\nindustries, but those aren’t the industries we’re talking about.)' metadata={'source': 'https://d1lamhf6l6yk6d.cloudfront.net/uploads/2021/08/The-pmarca-Blog-Archives.pdf', 'file_path': 'https://d1lamhf6l6yk6d.cloudfront.net/uploads/2021/08/The-pmarca-Blog-Archives.pdf', 'page': 127, 'total_pages': 195, 'format': 'PDF 1.3', 'title': 'The Pmarca Blog Archives', 'author': '', 'subject': '', 'keywords': '', 'creator': '', 'producer': 'Mac OS X 10.10 Quartz PDFContext', 'creationDate': "D:20150110020418Z00'00'", 'modDate': "D:20150110020418Z00'00'", 'trapped': '', '_id': 'e6ab142686cd4b1da4b3bee8e26bac79', '_collection_name': 'PMarca Blogs'}

# %% [markdown]
# ### Creating a RAG Chain
#
# Now that we have the "R" in RAG taken care of - let's look at creating the "AG"!

# %% [markdown]
# #### Creating a Prompt Template
#
# There are a few different ways we could create our prompt template - we could create a custom template, as seen in the code below, or we could simply pull a prompt from the prompt hub! Let's look at an example of that!

# %%
from langchain import hub

retrieval_qa_prompt = hub.pull("langchain-ai/retrieval-qa-chat")

# %%
print(retrieval_qa_prompt.messages[0].prompt.template)
# Out:
# Answer any use questions based solely on the context below:
#
# <context>
# {context}
# </context>

# %% [markdown]
# As you can see - the prompt template is simple (and has a small error) - so we'll create our own to be a bit more specific!

# %%
from langchain.prompts import ChatPromptTemplate

template = """Answer the question based only on the following context. If you cannot answer the question with the context, please respond with 'I don't know':

Context:
{context}

Question:
{question}
"""

prompt = ChatPromptTemplate.from_template(template)

# %% [markdown]
# #### Setting Up our Basic QA Chain
#
# Now we can instantiate our basic RAG chain!
#
# We'll use LCEL directly just to see an example of it - but you could just as easily use an abstraction here to achieve the same goal!
#
# We'll also ensure to pass-through our context - which is critical for RAGAS.

# %%
from operator import itemgetter

from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough

primary_qa_llm = ChatOpenAI(model_name="gpt-3.5-turbo", temperature=0)

retrieval_augmented_qa_chain = (
    # INVOKE CHAIN WITH: {"question" : "<<SOME USER QUESTION>>"}
    # "question" : populated by getting the value of the "question" key
    # "context"  : populated by getting the value of the "question" key and chaining it into the base_retriever
    {"context": itemgetter("question") | retriever, "question": itemgetter("question")}
    # "context"  : is assigned to a RunnablePassthrough object (will not be called or considered in the next step)
    #              by getting the value of the "context" key from the previous step
    | RunnablePassthrough.assign(context=itemgetter("context"))
    # "response" : the "context" and "question" values are used to format our prompt object and then piped
    #              into the LLM and stored in a key called "response"
    # "context"  : populated by getting the value of the "context" key from the previous step
    | {"response": prompt | primary_qa_llm, "context": itemgetter("context")}
)

# %% [markdown]
# ####🏗️ Activity #1:
#
# Describe the pipeline shown above in simple terms. You can include a diagram if desired.
#
# Step 1 -  {"context": itemgetter("question") | retriever, "question": itemgetter("question")}, the itemgetter("question") retrieves the user’s question and sends it down to parallel paths. The 2 outputs are "context" (i.e. the relevant information found by the retriever) and "question" (i.e the original question).
# Step 2 -  RunnablePassthrough.assign(context=itemgetter("context")), the itemgetter("context") extracts the context found in the first step and then passes it along to the next runnable step.
# Step 3 -  {"response": prompt | primary_qa_llm, "context": itemgetter("context")}, the question and the retrieved context are combined into a format suitable for a language model (prompt). This meta-prompt is then sent to the LLM, which generates a response. Two outputs are produced - "response" (the answer generated by the language model) and "context" (the original context is kept for reference or further use).

# %% [markdown]
# Let's test it out!

# %%
question = "What is a rule of thumb for selecting an industry to invest in?"

result = retrieval_augmented_qa_chain.invoke({"question" : question})

print(result["response"].content)
# Out:
# The rule of thumb for selecting an industry to invest in is to get right to the center of it.

# %%
question = "What did Pink Floyd have to say about how to proceed when investing in a new industry?"

result = retrieval_augmented_qa_chain.invoke({"question" : question})

print(result["response"].content)
print(result["context"])
# Out:
# I don't know.
# [Document(page_content='ask if you can call them again if things change.\nTrust me — they’d much rather be saying “yes” than “no” —\nthey need all the good investments they can get.\nSecond, consider the environment.', metadata={'source': 'https://d1lamhf6l6yk6d.cloudfront.net/uploads/2021/08/The-pmarca-Blog-Archives.pdf', 'file_path': 'https://d1lamhf6l6yk6d.cloudfront.net/uploads/2021/08/The-pmarca-Blog-Archives.pdf', 'page': 15, 'total_pages': 195, 'format': 'PDF 1.3', 'title': 'The Pmarca Blog Archives', 'author': '', 'subject': '', 'keywords': '', 'creator': '', 'producer': 'Mac OS X 10.10 Quartz PDFContext', 'creationDate': "D:20150110020418Z00'00'", 'modDate': "D:20150110020418Z00'00'", 'trapped': '', '_id': '05368de376b642d180878c172a48d6d3', '_collection_name': 'PMarca Blogs'}), Document(page_content='watching carefully — if everyone agrees right up front that\nwhatever you are doing makes total sense, it probably isn’t a new\nand radical enough idea to justify a new company.', metadata={'source': 'https://d1lamhf6l6yk6d.cloudfront.net/uploads/2021/08/The-pmarca-Blog-Archives.pdf', 'file_path': 'https://d1lamhf6l6yk6d.cloudfront.net/uploads/2021/08/The-pmarca-Blog-Archives.pdf', 'page': 152, 'total_pages': 195, 'format': 'PDF 1.3', 'title': 'The Pmarca Blog Archives', 'author': '', 'subject': '', 'keywords': '', 'creator': '', 'producer': 'Mac OS X 10.10 Quartz PDFContext', 'creationDate': "D:20150110020418Z00'00'", 'modDate': "D:20150110020418Z00'00'", 'trapped': '', '_id': '14fe5b5647ef444495cb14654d1cfc28', '_collection_name': 'PMarca Blogs'}), Document(page_content='Third rule:\nIn a rapidly changing Held like technology, the best place to\nget experience when you’re starting out is in younger, high-\ngrowth companies.', metadata={'source': 'https://d1lamhf6l6yk6d.cloudfront.net/uploads/2021/08/The-pmarca-Blog-Archives.pdf', 'file_path': 'https://d1lamhf6l6yk6d.cloudfront.net/uploads/2021/08/The-pmarca-Blog-Archives.pdf', 'page': 127, 'total_pages': 195, 'format': 'PDF 1.3', 'title': 'The Pmarca Blog Archives', 'author': '', 'subject': '', 'keywords': '', 'creator': '', 'producer': 'Mac OS X 10.10 Quartz PDFContext', 'creationDate': "D:20150110020418Z00'00'", 'modDate': "D:20150110020418Z00'00'", 'trapped': '', '_id': 'd4b86ad778fb48ea926842e2e3773852', '_collection_name': 'PMarca Blogs'}), Document(page_content='necessary supply of oil, gas, music, and movies.\nIf you’re going to enter an old industry, make sure to do it on\nthe side of the forces of radical change that threaten to up-end', metadata={'source': 'https://d1lamhf6l6yk6d.cloudfront.net/uploads/2021/08/The-pmarca-Blog-Archives.pdf', 'file_path': 'https://d1lamhf6l6yk6d.cloudfront.net/uploads/2021/08/The-pmarca-Blog-Archives.pdf', 'page': 125, 'total_pages': 195, 'format': 'PDF 1.3', 'title': 'The Pmarca Blog Archives', 'author': '', 'subject': '', 'keywords': '', 'creator': '', 'producer': 'Mac OS X 10.10 Quartz PDFContext', 'creationDate': "D:20150110020418Z00'00'", 'modDate': "D:20150110020418Z00'00'", 'trapped': '', '_id': 'a4502dfc5fb24a2d9a846e32f1783d64', '_collection_name': 'PMarca Blogs'})]

# %% [markdown]
# We can already see that there are some improvements we could make here.
#
# For now, let's switch gears to RAGAS to see how we can leverage that tool to provide us insight into how our pipeline is performing!

# %% [markdown]
# ## Task 4: Synthetic Dataset Generation for Evaluation using Ragas
#
# Ragas is a powerful library that lets us evaluate our RAG pipeline by collecting input/output/context triplets and obtaining metrics relating to a number of different aspects of our RAG pipeline.
#
# We'll be evaluating on every core metric today, but in order to do that - we'll need to create a test set. Luckily for us, Ragas can do that directly!

# %% [markdown]
# ### Synthetic Test Set Generation
#
# We can leverage Ragas' [`Synthetic Test Data generation`](https://docs.ragas.io/en/stable/concepts/testset_generation.html) functionality to generate our own synthetic QC pairs - as well as a synthetic ground truth - quite easily!

# %%
loader = PyMuPDFLoader(
    "https://d1lamhf6l6yk6d.cloudfront.net/uploads/2021/08/The-pmarca-Blog-Archives.pdf",
)

eval_documents = loader.load()

text_splitter_eval = RecursiveCharacterTextSplitter(
    chunk_size = 600,
    chunk_overlap = 50
)

eval_documents = text_splitter_eval.split_documents(eval_documents)

# %% [markdown]
# ####❓ Question #2:
#
# Why is it important to split our documents using different parameters when creating our synthetic data?
#
# 1. Balanced data for training and eval: Splitting documents using different parameters helps in creating a balanced dataset where different types of context and content granularity.
# 2. Realistic query generation: Splitting documents in different ways ensures that synthetic queries mimic real-world scenarios where users might seek information at different granularities.
# 3. Enhanced model generalization: When a model is trained or evaluated on data that has been split in various ways, it is exposed to a broader range of textual patterns and structures. This enhances the model's ability to generalize from the training data to unseen data, improving its performance in real-world applications.

# %%
len(eval_documents)
# Out:
# 624

# %% [markdown]
# > NOTE: 🛑 Using this notebook as presented will occur a charge of ~$3USD from OpenAI usage. Most of this cost is produced by the Synthetic Data Generation step - if you want to reduce costs, please use the provided commented code to leverage GPT-3.5-Turbo as the critic_llm. If you're attempting to create a lot of samples please be aware of cost, as well as rate limits. 🛑

# %%
from ragas.testset.generator import TestsetGenerator
from ragas.testset.evolutions import simple, reasoning, multi_context
from langchain_openai import ChatOpenAI, OpenAIEmbeddings

generator_llm = ChatOpenAI(model="gpt-3.5-turbo-16k")
# critic_llm = ChatOpenAI(model="gpt-3.5-turbo") <--- If you don't have GPT-4 access, or to reduce cost/rate limiting issues.
critic_llm = ChatOpenAI(model="gpt-4o")
embeddings = OpenAIEmbeddings()

generator = TestsetGenerator.from_langchain(
    generator_llm,
    critic_llm,
    embeddings
)

distributions = {
    simple: 0.5,
    multi_context: 0.4,
    reasoning: 0.1
}

testset = generator.generate_with_langchain_docs(eval_documents, 20, distributions, is_async = False)
testset.to_pandas()
# Out:
# embedding nodes:   0%|          | 0/1248 [00:00<?, ?it/s]
# Filename and doc_id are the same for all nodes.
# Generating:   0%|          | 0/20 [00:00<?, ?it/s]
#                                              question  \
# 0   What is the emotional incentive that founders ...
# 1   What is the impact of shifting towards restric...
# 2   How is the caliber of a startup team related t...
# 3   What is the importance of having a technical e...
# 4   What is the purpose of the Action folder in em...
# 5   What are some examples of older services that ...
# 6   What factors determine the peak age for creati...
# 7   What is the suggested approach for handling du...
# 8   What is a key feature of Peter Hamilton's stor...
# 9   What are some strategies for undergrads to gai...
# 10  What is the main challenge in finding a new pr...
# 11  What qualities are necessary for director/VP m...
# 12  What are some effective methods for connecting...
# 13  What degrees are most valuable for entering a ...
# 14  How does inconsistency avoidance affect habit ...
# 15  What does the author think of Peter Hamilton's...
# 16  How can interruptions be minimized and focus m...
# 17  What is the purpose of using temporary subfold...
# 18  What are the potential setbacks and risks if a...
# 19  Which folder is for follow-up on commitments m...
#
#                                              contexts  \
# 0   [and give her a large stock-option grant with ...
# 1   [of creating value. And new hires will by deXn...
# 2   [Let’s start by deXning terms.\nThe caliber of...
# 3   [workforce in a high-impact way when you gradu...
# 4   [you can reply to a lot of messages with “I’m ...
# 5   [billion people online now. That is a very lar...
# 6   [ods when productivity is highest, the peak ag...
# 7   [Nuke all matrices. Nuke all dual reporting st...
# 8   [pandemics, nuclear terrorist attacks, governm...
# 9   [undergrads to do some of the work, and being ...
# 10  [problem — your original product cycle has pea...
# 11  [strong, sharp, aggressive, ambitious director...
# 12  [and identifying those VCs and screening out a...
# 13  [workforce in a high-impact way when you gradu...
# 14  [Five: Inconsistency-Avoidance Tendency\n[Peop...
# 15  [pandemics, nuclear terrorist attacks, governm...
# 16  [Answer the Xrst one when it rings, but never ...
# 17  [you can reply to a lot of messages with “I’m ...
# 18  [Here’s why you shouldn’t do that:\nWhat are t...
# 19  [keep three standing email folders: Pending, R...
#
#                                          ground_truth evolution_type  \
# 0   Founders naturally have an emotional incentive...         simple
# 1   Microsoa's stock has been flat as a pancake in...         simple
# 2   The caliber of a startup team is related to th...         simple
# 3   Having a technical element in undergraduate de...         simple
# 4   The purpose of the Action folder in email orga...         simple
# 5   newspapers, magazines, television, movie theat...         simple
# 6   The expected age optimum for quantity and qual...         simple
# 7                 Nuke all dual reporting structures.         simple
# 8   Peter Hamilton's storytelling style in his spa...         simple
# 9   aggressively pursue internship and co-op progr...         simple
# 10  The main challenge in finding a new product cy...  multi_context
# 11  The qualities necessary for director/VP manage...  multi_context
# 12  The best way to develop contacts with VCs is t...  multi_context
# 13  Engineering degrees, computer science degrees,...  multi_context
# 14  Inconsistency-Avoidance Tendency leads people ...  multi_context
# 15  The author thinks highly of Peter Hamilton's s...  multi_context
# 16  One of the best and easiest ways to avoid dist...  multi_context
# 17  The purpose of using temporary subfolders in e...  multi_context
# 18  The potential setbacks and risks if a company ...      reasoning
# 19                                            Pending      reasoning
#
#                                              metadata  episode_done
# 0   [{'source': 'https://d1lamhf6l6yk6d.cloudfront...          True
# 1   [{'source': 'https://d1lamhf6l6yk6d.cloudfront...          True
# 2   [{'source': 'https://d1lamhf6l6yk6d.cloudfront...          True
# 3   [{'source': 'https://d1lamhf6l6yk6d.cloudfront...          True
# 4   [{'source': 'https://d1lamhf6l6yk6d.cloudfront...          True
# 5   [{'source': 'https://d1lamhf6l6yk6d.cloudfront...          True
# 6   [{'source': 'https://d1lamhf6l6yk6d.cloudfront...          True
# 7   [{'source': 'https://d1lamhf6l6yk6d.cloudfront...          True
# 8   [{'source': 'https://d1lamhf6l6yk6d.cloudfront...          True
# 9   [{'source': 'https://d1lamhf6l6yk6d.cloudfront...          True
# 10  [{'source': 'https://d1lamhf6l6yk6d.cloudfront...          True
# 11  [{'source': 'https://d1lamhf6l6yk6d.cloudfront...          True
# 12  [{'source': 'https://d1lamhf6l6yk6d.cloudfront...          True
# 13  [{'source': 'https://d1lamhf6l6yk6d.cloudfront...          True
# 14  [{'source': 'https://d1lamhf6l6yk6d.cloudfront...          True
# 15  [{'source': 'https://d1lamhf6l6yk6d.cloudfront...          True
# 16  [{'source': 'https://d1lamhf6l6yk6d.cloudfront...          True
# 17  [{'source': 'https://d1lamhf6l6yk6d.cloudfront...          True
# 18  [{'source': 'https://d1lamhf6l6yk6d.cloudfront...          True
# 19  [{'source': 'https://d1lamhf6l6yk6d.cloudfront...          True

# %% [markdown]
# ####❓ Question #3:
#
# `{simple: 0.5, reasoning: 0.25, multi_context: 0.25}`
#
# What exactly does this mapping refer to?
#
# Simple tests will be 50% of the generated cases, multi_context 25%, and reasoning 25%.
# Reasoning means rewriting the question in a way enhancing reasoning to answer it more effectively.
# Multi-Context means rewriting the question in a manner that scans through different sections or chunks to get a more perfect answer.
#
#
# > NOTE: Check out the Ragas documentation on this generation process [here](https://docs.ragas.io/en/stable/concepts/testset_generation.html).

# %% [markdown]
# Let's look at the output and see what we can learn about it!

# %%
testset.test_data[0]
# Out:
# DataRow(question='What is the emotional incentive that founders have towards the success of their company?', contexts=['and give her a large stock-option grant with four-year vesting,\nand you can guarantee she will sell the company in year four.\nGive her a stock-option grant with accelerated vesting on\nchange of control and she will sell the company sooner than\nthat. Founders can get tripped up on this because they naturally\nhave an emotional incentive to see the company succeed that\nhired executives oaen do not share.\nAnd of course, never get caught between a venture capitalist and\nher incentives.\nTwo: Liking/Loving Tendency\n…[W]hat will a man naturally come to like and love, apart from his'], ground_truth='Founders naturally have an emotional incentive to see the company succeed.', evolution_type='simple', metadata=[{'source': 'https://d1lamhf6l6yk6d.cloudfront.net/uploads/2021/08/The-pmarca-Blog-Archives.pdf', 'file_path': 'https://d1lamhf6l6yk6d.cloudfront.net/uploads/2021/08/The-pmarca-Blog-Archives.pdf', 'page': 150, 'total_pages': 195, 'format': 'PDF 1.3', 'title': 'The Pmarca Blog Archives', 'author': '', 'subject': '', 'keywords': '', 'creator': '', 'producer': 'Mac OS X 10.10 Quartz PDFContext', 'creationDate': "D:20150110020418Z00'00'", 'modDate': "D:20150110020418Z00'00'", 'trapped': ''}])

# %% [markdown]
# ### Generating Responses with RAG Pipeline
#
# Now that we have some QC pairs, and some ground truths, let's evaluate our RAG pipeline using Ragas.
#
# The process is, again, quite straightforward - thanks to Ragas and LangChain!
#
# Let's start by extracting our questions and ground truths from our create testset.
#
# We can start by converting our test dataset into a Pandas DataFrame.

# %%
test_df = testset.to_pandas()

# %%
test_df
# Out:
#                                              question  \
# 0   What is the emotional incentive that founders ...
# 1   What is the impact of shifting towards restric...
# 2   How is the caliber of a startup team related t...
# 3   What is the importance of having a technical e...
# 4   What is the purpose of the Action folder in em...
# 5   What are some examples of older services that ...
# 6   What factors determine the peak age for creati...
# 7   What is the suggested approach for handling du...
# 8   What is a key feature of Peter Hamilton's stor...
# 9   What are some strategies for undergrads to gai...
# 10  What is the main challenge in finding a new pr...
# 11  What qualities are necessary for director/VP m...
# 12  What are some effective methods for connecting...
# 13  What degrees are most valuable for entering a ...
# 14  How does inconsistency avoidance affect habit ...
# 15  What does the author think of Peter Hamilton's...
# 16  How can interruptions be minimized and focus m...
# 17  What is the purpose of using temporary subfold...
# 18  What are the potential setbacks and risks if a...
# 19  Which folder is for follow-up on commitments m...
#
#                                              contexts  \
# 0   [and give her a large stock-option grant with ...
# 1   [of creating value. And new hires will by deXn...
# 2   [Let’s start by deXning terms.\nThe caliber of...
# 3   [workforce in a high-impact way when you gradu...
# 4   [you can reply to a lot of messages with “I’m ...
# 5   [billion people online now. That is a very lar...
# 6   [ods when productivity is highest, the peak ag...
# 7   [Nuke all matrices. Nuke all dual reporting st...
# 8   [pandemics, nuclear terrorist attacks, governm...
# 9   [undergrads to do some of the work, and being ...
# 10  [problem — your original product cycle has pea...
# 11  [strong, sharp, aggressive, ambitious director...
# 12  [and identifying those VCs and screening out a...
# 13  [workforce in a high-impact way when you gradu...
# 14  [Five: Inconsistency-Avoidance Tendency\n[Peop...
# 15  [pandemics, nuclear terrorist attacks, governm...
# 16  [Answer the Xrst one when it rings, but never ...
# 17  [you can reply to a lot of messages with “I’m ...
# 18  [Here’s why you shouldn’t do that:\nWhat are t...
# 19  [keep three standing email folders: Pending, R...
#
#                                          ground_truth evolution_type  \
# 0   Founders naturally have an emotional incentive...         simple
# 1   Microsoa's stock has been flat as a pancake in...         simple
# 2   The caliber of a startup team is related to th...         simple
# 3   Having a technical element in undergraduate de...         simple
# 4   The purpose of the Action folder in email orga...         simple
# 5   newspapers, magazines, television, movie theat...         simple
# 6   The expected age optimum for quantity and qual...         simple
# 7                 Nuke all dual reporting structures.         simple
# 8   Peter Hamilton's storytelling style in his spa...         simple
# 9   aggressively pursue internship and co-op progr...         simple
# 10  The main challenge in finding a new product cy...  multi_context
# 11  The qualities necessary for director/VP manage...  multi_context
# 12  The best way to develop contacts with VCs is t...  multi_context
# 13  Engineering degrees, computer science degrees,...  multi_context
# 14  Inconsistency-Avoidance Tendency leads people ...  multi_context
# 15  The author thinks highly of Peter Hamilton's s...  multi_context
# 16  One of the best and easiest ways to avoid dist...  multi_context
# 17  The purpose of using temporary subfolders in e...  multi_context
# 18  The potential setbacks and risks if a company ...      reasoning
# 19                                            Pending      reasoning
#
#                                              metadata  episode_done
# 0   [{'source': 'https://d1lamhf6l6yk6d.cloudfront...          True
# 1   [{'source': 'https://d1lamhf6l6yk6d.cloudfront...          True
# 2   [{'source': 'https://d1lamhf6l6yk6d.cloudfront...          True
# 3   [{'source': 'https://d1lamhf6l6yk6d.cloudfront...          True
# 4   [{'source': 'https://d1lamhf6l6yk6d.cloudfront...          True
# 5   [{'source': 'https://d1lamhf6l6yk6d.cloudfront...          True
# 6   [{'source': 'https://d1lamhf6l6yk6d.cloudfront...          True
# 7   [{'source': 'https://d1lamhf6l6yk6d.cloudfront...          True
# 8   [{'source': 'https://d1lamhf6l6yk6d.cloudfront...          True
# 9   [{'source': 'https://d1lamhf6l6yk6d.cloudfront...          True
# 10  [{'source': 'https://d1lamhf6l6yk6d.cloudfront...          True
# 11  [{'source': 'https://d1lamhf6l6yk6d.cloudfront...          True
# 12  [{'source': 'https://d1lamhf6l6yk6d.cloudfront...          True
# 13  [{'source': 'https://d1lamhf6l6yk6d.cloudfront...          True
# 14  [{'source': 'https://d1lamhf6l6yk6d.cloudfront...          True
# 15  [{'source': 'https://d1lamhf6l6yk6d.cloudfront...          True
# 16  [{'source': 'https://d1lamhf6l6yk6d.cloudfront...          True
# 17  [{'source': 'https://d1lamhf6l6yk6d.cloudfront...          True
# 18  [{'source': 'https://d1lamhf6l6yk6d.cloudfront...          True
# 19  [{'source': 'https://d1lamhf6l6yk6d.cloudfront...          True

# %%
test_questions = test_df["question"].values.tolist()
test_groundtruths = test_df["ground_truth"].values.tolist()

# %% [markdown]
# Now we'll generate responses using our RAG pipeline using the questions we've generated - we'll also need to collect our retrieved contexts for each question.
#
# We'll do this in a simple loop to see exactly what's happening!

# %%
answers = []
contexts = []

for question in test_questions:
  response = retrieval_augmented_qa_chain.invoke({"question" : question})
  answers.append(response["response"].content)
  contexts.append([context.page_content for context in response["context"]])

# %% [markdown]
# Now we can wrap our information in a Hugging Face dataset for use in the Ragas library.

# %%
from datasets import Dataset

response_dataset = Dataset.from_dict({
    "question" : test_questions,
    "answer" : answers,
    "contexts" : contexts,
    "ground_truth" : test_groundtruths
})

# %% [markdown]
# Let's take a peek and see what that looks like!

# %%
response_dataset[0]
# Out:
# {'question': 'What is the emotional incentive that founders have towards the success of their company?',
#  'answer': 'Founders have an emotional incentive to see the company succeed.',
#  'contexts': ['have an emotional incentive to see the company succeed that\nhired executives oaen do not share.\nAnd of course, never get caught between a venture capitalist and\nher incentives.',
#   'Ironically, once a startup is successful, and you ask the founders\nwhat made it successful, they will usually cite all kinds of things',
#   'bitterness, disillusionment, cynicism, bad morale, contempt for\nmanagement, and depression.\nAnd you as the founder have much less inYuence over this than\nyou’ll think you do.',
#   'usually a plus for a startup, since it leads to greater commitment\non the part of the entrepreneur and the team. (And yes, I am in\nfavor of blood oaths for startups.)'],
#  'ground_truth': 'Founders naturally have an emotional incentive to see the company succeed.'}

# %% [markdown]
# # 🤝 Breakout Room Part #2

# %% [markdown]
# ## Task 1: Evaluating our Pipeline with Ragas
#
# Now that we have our response dataset - we can finally get into the "meat" of Ragas - evaluation!
#
# First, we'll import the desired metrics, then we can use them to evaluate our created dataset!
#
# Check out the specific metrics we'll be using in the Ragas documentation:
#
# - [Faithfulness](https://docs.ragas.io/en/stable/concepts/metrics/faithfulness.html)
# - [Answer Relevancy](https://docs.ragas.io/en/stable/concepts/metrics/answer_relevance.html)
# - [Context Precision](https://docs.ragas.io/en/stable/concepts/metrics/context_precision.html)
# - [Context Recall](https://docs.ragas.io/en/stable/concepts/metrics/context_recall.html)
# - [Answer Correctness](https://docs.ragas.io/en/stable/concepts/metrics/answer_correctness.html)
#
# See the accompanied presentation for more in-depth explanations about each of the metrics!

# %%
from ragas import evaluate
from ragas.metrics import (
    faithfulness,
    answer_relevancy,
    answer_correctness,
    context_recall,
    context_precision,
)

metrics = [
    faithfulness,
    answer_relevancy,
    context_recall,
    context_precision,
    answer_correctness,
]

# %% [markdown]
# All that's left to do is call "evaluate" and away we go!

# %%
results = evaluate(response_dataset, metrics)
# Out:
# Evaluating:   0%|          | 0/100 [00:00<?, ?it/s]
# Exception in thread Thread-14:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/opt/anaconda3/lib/python3.11/site-packages/ragas/executor.py", line 95, in run
#     results = self.loop.run_until_complete(self._aresults())
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/asyncio/base_events.py", line 653, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/ragas/executor.py", line 83, in _aresults
#     raise e
#   File "/opt/anaconda3/lib/python3.11/site-packages/ragas/executor.py", line 78, in _aresults
#     r = await future
#         ^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/asyncio/tasks.py", line 615, in _wait_for_one
#     return f.result()  # May raise f.exception().
#            ^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/ragas/executor.py", line 37, in sema_coro
#     return await coro
#            ^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/ragas/executor.py", line 111, in wrapped_callable_async
#     return counter, await callable(*args, **kwargs)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/ragas/metrics/base.py", line 125, in ascore
#     raise e
#   File "/opt/anaconda3/lib/python3.11/site-packages/ragas/metrics/base.py", line 121, in ascore
#     score = await self._ascore(row=row, callbacks=group_cm, is_async=is_async)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/ragas/metrics/_context_precision.py", line 161, in _ascore
#     results = await self.llm.generate(
#               ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/ragas/llms/base.py", line 93, in generate
#     return await agenerate_text_with_retry(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/tenacity/_asyncio.py", line 88, in async_wrapped
#     return await fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/tenacity/_asyncio.py", line 47, in __call__
#     do = self.iter(retry_state=retry_state)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/tenacity/__init__.py", line 325, in iter
#     raise retry_exc.reraise()
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/tenacity/__init__.py", line 158, in reraise
#     raise self.last_attempt.result()
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/opt/anaconda3/lib/python3.11/site-packages/tenacity/_asyncio.py", line 50, in __call__
#     result = await fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/ragas/llms/base.py", line 170, in agenerate_text
#     return await self.langchain_llm.agenerate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 687, in agenerate_prompt
#     return await self.agenerate(
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 647, in agenerate
#     raise exceptions[0]
#   File "/opt/anaconda3/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 832, in _agenerate_with_cache
#     result = await self._agenerate(
#              ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 672, in _agenerate
#     response = await self.async_client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 1289, in create
#     return await self._post(
#            ^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/openai/_base_client.py", line 1805, in post
#     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/openai/_base_client.py", line 1503, in request
#     return await self._request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/openai/_base_client.py", line 1584, in _request
#     return await self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/openai/_base_client.py", line 1630, in _retry_request
#     return await self._request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/openai/_base_client.py", line 1584, in _request
#     return await self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/openai/_base_client.py", line 1630, in _retry_request
#     return await self._request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/openai/_base_client.py", line 1599, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-3.5-turbo in organization org-X3sN4ga8eVEJOxWq5ePY8ePN on tokens per min (TPM): Limit 60000, Used 59379, Requested 1167. Please try again in 546ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# ---------------------------------------------------------------------------
# ExceptionInRunner                         Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 results = evaluate(response_dataset, metrics)
#
# File /opt/anaconda3/lib/python3.11/site-packages/ragas/evaluation.py:250, in evaluate(dataset, metrics, llm, embeddings, callbacks, in_ci, is_async, run_config, raise_exceptions, column_map)
#     247     if not evaluation_group_cm.ended:
#     248         evaluation_rm.on_chain_error(e)
# --> 250     raise e
#     251 else:
#     252     result = Result(
#     253         scores=Dataset.from_list(scores),
#     254         dataset=dataset,
#     255         binary_columns=binary_metrics,
#     256     )
#
# File /opt/anaconda3/lib/python3.11/site-packages/ragas/evaluation.py:232, in evaluate(dataset, metrics, llm, embeddings, callbacks, in_ci, is_async, run_config, raise_exceptions, column_map)
#     230 results = executor.results()
#     231 if results == []:
# --> 232     raise ExceptionInRunner()
#     234 # convert results to dataset_like
#     235 for i, _ in enumerate(dataset):
#
# ExceptionInRunner: The runner thread which was running the jobs raised an exeception. Read the traceback above to debug it. You can also pass `raise_exceptions=False` incase you want to show only a warning message instead.

# %%
results
# Out:
# {'faithfulness': 0.6255, 'answer_relevancy': 0.8526, 'context_recall': 0.6500, 'context_precision': 0.7583, 'answer_correctness': 0.5520}

# %%
results_df = results.to_pandas()
results_df
# Out:
#                                              question  \
# 0   What are the potential risks and challenges fa...
# 1   How can a transformative deal inject energy ba...
# 2   Who is quoted as saying "This fucking job ain'...
# 3   What is Los Angeles known for in terms of oppo...
# 4   How can blogging about their point of view hel...
# 5   Are the anticipated career peaks for creators ...
# 6   What is the impact of accelerated vesting on c...
# 7   What is the benefit of combining a useful grad...
# 8   What are some ways to bootstrap a business bef...
# 9   What is Richard Morgan's opinion of Peter Hami...
# 10  What are the main responsibilities of a startu...
# 11  How does the productivity-creativity relations...
# 12  What are the consequences and trade-offs of th...
# 13  What is the correlation between startup team c...
# 14  How do technical degrees demonstrate commitmen...
# 15  According to "A Perfect Mess," what is one tac...
# 16  What was MySpace's revenue in 2007, given the ...
# 17  How can interruptions be minimized and focus m...
# 18  Which folder is for follow-up on commitments m...
# 19  How does perceived risk impact decision-making...
#
#                                                answer  \
# 0   Not raising enough money risks the survival of...
# 1   A transformative deal can inject energy back i...
# 2                                       Tommy Lasorda
# 3   Los Angeles is known for opportunities and ind...
# 4   Blogging about their point of view can help an...
# 5                                             Earlier
# 6   Accelerated vesting on change of control can l...
# 7          The benefit is becoming a "double threat."
# 8   Some ways to bootstrap a business before raisi...
# 9   Richard Morgan thinks that Peter Hamilton is t...
# 10  The main responsibilities of a startup executi...
# 11  The productivity-creativity relationship in a ...
# 12  The consequences of not raising enough money i...
# 13  The correlation between startup team caliber a...
# 14  Technical degrees demonstrate commitment to fu...
# 15                   Avoiding scheduling commitments.
# 16  MySpace's revenue in 2007 was nearly $300 mill...
# 17  Interruptions can be minimized and focus maint...
# 18                                     Pending folder
# 19                                      I don't know.
#
#                                              contexts  \
# 0   [Here’s why you shouldn’t do that:\nWhat are t...
# 1   [the story. Reintroduce curiosity.\nWhen all e...
# 2   [have to do. But these are the 9 most importan...
# 3   [the city where all the action is happening.\n...
# 4   [esting things going on, about their point of ...
# 5   [early, end late, and produce at above-average...
# 6   [Give her a stock-option grant with accelerate...
# 7   [degree, you are much better oW combining it w...
# 8   [This obviously raises the issue of how you’re...
# 9   [ders and executions around the clock. Haven’t...
# 10  [more as administrators and bureaucrats.\n•\nB...
# 11  [the connection between productive precocity, ...
# 12  [Here’s why you shouldn’t do that:\nWhat are t...
# 13  [Let’s start by deXning terms.\nThe caliber of...
# 14  [path to doing anything big.\n•\nPlus, technic...
# 15  [By not keeping a schedule, I mean: refuse to ...
# 16  [enue in 2007, and more in 2008.\nAs an indepe...
# 17  [one.\nHide in an iPod\nOne of the best and ea...
# 18  [the normal course of your day.\nFourth, aside...
# 19  [What are the layers of risk for a high-tech\n...
#
#                                          ground_truth  faithfulness  \
# 0   Not raising enough money risks the survival of...      1.000000
# 1                                                 nan      1.000000
# 2                             The great Tommy Lasorda      0.000000
# 3   Los Angeles is known for opportunities and ind...      0.500000
# 4   Blogging about their point of view can help an...      0.833333
# 5                                                 nan           NaN
# 6   Give her a stock-option grant with accelerated...      1.000000
# 7   You become a "double threat" by combining a us...           NaN
# 8   Try to raise angel money, or bootstrap oW of i...      0.500000
# 9   Richard Morgan blurbed Peter Hamilton's storyt...      1.000000
# 10  A startup executive is expected to be a primar...      0.666667
# 11  Quality of output does not vary by age in a cr...      0.500000
# 12  The consequences and trade-offs of the money r...      0.500000
# 13                                                nan      0.000000
# 14  Technical degrees demonstrate commitment to fu...      0.800000
# 15  Not keeping a schedule and avoiding scheduling...      1.000000
# 16                                       $300 million      1.000000
# 17  One of the best and easiest ways to avoid dist...      0.333333
# 18                                            Pending      0.000000
# 19  In a startup with multiple founders and one CE...           NaN
#
#     answer_relevancy  context_recall  context_precision  answer_correctness
# 0           0.921018        0.333333           0.805556            0.529155
# 1           1.000000        0.000000           0.000000            0.186865
# 2           0.983167        1.000000           1.000000            0.992112
# 3           1.000000        1.000000           1.000000            1.000000
# 4           0.975135        1.000000           1.000000            0.656363
# 5           0.000000        0.500000           0.833333            0.953437
# 6           0.949391        1.000000           1.000000            0.730933
# 7           0.982863        1.000000           0.833333            0.718952
# 8           1.000000        1.000000           1.000000            0.562501
# 9           0.864006        1.000000           0.833333            0.216650
# 10          0.940006        0.333333           0.638889            0.799564
# 11          0.925137        0.250000           1.000000            0.225095
# 12          0.897898        0.500000           0.638889            0.645408
# 13          0.995562        0.000000           0.000000            0.185721
# 14          0.938170        0.750000           1.000000            0.475377
# 15          0.860719        1.000000           0.916667            0.732639
# 16          0.960172        1.000000           0.500000            0.582823
# 17          0.999999        0.333333           1.000000            0.439268
# 18          0.858847        1.000000           0.250000            0.222738
# 19          0.000000        0.000000           0.916667            0.184041

# %% [markdown]
# ## Task 2: Making Adjustments to our RAG Pipeline
#
# Now that we have established a baseline - we can see how any changes impact our pipeline's performance!
#
# Let's modify our retriever and see how that impacts our Ragas metrics!
#
# > NOTE: MultiQueryRetriever is expanded on [here](https://python.langchain.com/docs/modules/data_connection/retrievers/MultiQueryRetriever) but for now, the implementation is not important to our lesson!

# %%
from langchain.retrievers import MultiQueryRetriever

advanced_retriever = MultiQueryRetriever.from_llm(retriever=retriever, llm=primary_qa_llm)

# %% [markdown]
# We'll also re-create our RAG pipeline using the abstractions that come packaged with LangChain v0.1.0!
#
# First, let's create a chain to "stuff" our documents into our context!

# %%
from langchain.chains.combine_documents import create_stuff_documents_chain

document_chain = create_stuff_documents_chain(primary_qa_llm, retrieval_qa_prompt)

# %% [markdown]
# Next, we'll create the retrieval chain!

# %%
from langchain.chains import create_retrieval_chain

retrieval_chain = create_retrieval_chain(advanced_retriever, document_chain)

# %%
response = retrieval_chain.invoke({"input": "Who is Taylor Swift fueding with?"})

# %%
print(response["answer"])
# Out:
# I'm sorry, but based on the context provided, I do not have information about any feud involving Taylor Swift.

# %%
response = retrieval_chain.invoke({"input": "Why are they fueding?"})

# %%
print(response["answer"])
# Out:
# The context provided does not mention any specific feud or conflict between individuals or groups. It primarily discusses factors influencing success in business, human behavior, and decision-making dynamics in companies. If you have a specific scenario or context in mind, please provide more details for a more accurate response.

# %% [markdown]
# Well, just from those responses this chain *feels* better - but lets see how it performs on our eval!
#
# Let's do the same process we did before to collect our pipeline's contexts and answers.

# %%
answers = []
contexts = []

for question in test_questions:
  response = retrieval_chain.invoke({"input" : question})
  answers.append(response["answer"])
  contexts.append([context.page_content for context in response["context"]])

# %% [markdown]
# Now we can convert this into a dataset, just like we did before.

# %%
response_dataset_advanced_retrieval = Dataset.from_dict({
    "question" : test_questions,
    "answer" : answers,
    "contexts" : contexts,
    "ground_truth" : test_groundtruths
})

# %% [markdown]
# Let's evaluate on the same metrics we did for the first pipeline and see how it does!

# %%
advanced_retrieval_results = evaluate(response_dataset_advanced_retrieval, metrics)
# Out:
# Evaluating:   0%|          | 0/100 [00:00<?, ?it/s]

# %%
advanced_retrieval_results_df = advanced_retrieval_results.to_pandas()
advanced_retrieval_results_df
# Out:
#                                              question  \
# 0   What are the potential risks and challenges fa...
# 1   How can a transformative deal inject energy ba...
# 2   Who is quoted as saying "This fucking job ain'...
# 3   What is Los Angeles known for in terms of oppo...
# 4   How can blogging about their point of view hel...
# 5   Are the anticipated career peaks for creators ...
# 6   What is the impact of accelerated vesting on c...
# 7   What is the benefit of combining a useful grad...
# 8   What are some ways to bootstrap a business bef...
# 9   What is Richard Morgan's opinion of Peter Hami...
# 10  What are the main responsibilities of a startu...
# 11  How does the productivity-creativity relations...
# 12  What are the consequences and trade-offs of th...
# 13  What is the correlation between startup team c...
# 14  How do technical degrees demonstrate commitmen...
# 15  According to "A Perfect Mess," what is one tac...
# 16  What was MySpace's revenue in 2007, given the ...
# 17  How can interruptions be minimized and focus m...
# 18  Which folder is for follow-up on commitments m...
# 19  How does perceived risk impact decision-making...
#
#                                                answer  \
# 0   Not raising enough money risks the survival of...
# 1   A transformative deal can inject energy back i...
# 2   The quote "This fucking job ain't that fucking...
# 3   Los Angeles is known for opportunities and ind...
# 4   Blogging about their point of view can help an...
# 5   The anticipated career peaks for creators who ...
# 6   Accelerated vesting on change of control can i...
# 7   Combining a useful graduate degree with a subs...
# 8   Some ways to bootstrap a business before raisi...
# 9   Richard Morgan views Peter Hamilton as the cle...
# 10  A startup executive must take personal respons...
# 11  The relationship between productivity and crea...
# 12  The consequences and trade-offs of the money r...
# 13  The caliber of a startup team can greatly impa...
# 14  Technical degrees demonstrate commitment to fu...
# 15  One tactic that can increase productivity by a...
# 16  MySpace's revenue in 2007 was nearly $300 mill...
# 17  Interruptions can be minimized and focus maint...
# 18  The folder for follow-up on commitments made b...
# 19  Perceived risk can impact decision-making in a...
#
#                                              contexts  \
# 0   [Here’s why you shouldn’t do that:\nWhat are t...
# 1   [ossiXed that the clear opportunity exists to ...
# 2   [then doesn’t know what the friend is currentl...
# 3   [the city where all the action is happening.\n...
# 4   [esting things going on, about their point of ...
# 5   [early, end late, and produce at above-average...
# 6   [Give her a stock-option grant with accelerate...
# 7   [degree, you are much better oW combining it w...
# 8   [This obviously raises the issue of how you’re...
# 9   [ders and executions around the clock. Haven’t...
# 10  [more as administrators and bureaucrats.\n•\nB...
# 11  [the connection between productive precocity, ...
# 12  [Here’s why you shouldn’t do that:\nWhat are t...
# 13  [Let’s start by deXning terms.\nThe caliber of...
# 14  [path to doing anything big.\n•\nPlus, technic...
# 15  [By not keeping a schedule, I mean: refuse to ...
# 16  [enue in 2007, and more in 2008.\nAs an indepe...
# 17  [one.\nHide in an iPod\nOne of the best and ea...
# 18  [the normal course of your day.\nFourth, aside...
# 19  [What are the layers of risk for a high-tech\n...
#
#                                          ground_truth  faithfulness  \
# 0   Not raising enough money risks the survival of...      0.666667
# 1                                                 nan      0.500000
# 2                             The great Tommy Lasorda      1.000000
# 3   Los Angeles is known for opportunities and ind...      1.000000
# 4   Blogging about their point of view can help an...      1.000000
# 5                                                 nan      0.666667
# 6   Give her a stock-option grant with accelerated...      0.250000
# 7   You become a "double threat" by combining a us...      1.000000
# 8   Try to raise angel money, or bootstrap oW of i...      1.000000
# 9   Richard Morgan blurbed Peter Hamilton's storyt...      0.000000
# 10  A startup executive is expected to be a primar...      1.000000
# 11  Quality of output does not vary by age in a cr...      0.800000
# 12  The consequences and trade-offs of the money r...      1.000000
# 13                                                nan      1.000000
# 14  Technical degrees demonstrate commitment to fu...      1.000000
# 15  Not keeping a schedule and avoiding scheduling...      0.000000
# 16                                       $300 million      0.500000
# 17  One of the best and easiest ways to avoid dist...      0.857143
# 18                                            Pending      0.000000
# 19  In a startup with multiple founders and one CE...      1.000000
#
#     answer_relevancy  context_recall  context_precision  answer_correctness
# 0           0.921043        1.000000           0.804167            0.346032
# 1           0.985384        0.000000           0.000000            0.180063
# 2           0.979978        1.000000           0.500000            0.717253
# 3           0.999999        1.000000           1.000000            0.883862
# 4           0.975714        1.000000           1.000000            0.747243
# 5           0.982765        0.000000           0.750000            0.184018
# 6           0.927667        1.000000           1.000000            0.897261
# 7           0.907999        1.000000           0.833333            0.538305
# 8           1.000000        1.000000           1.000000            0.559488
# 9           0.939448        1.000000           0.691667            0.614487
# 10          0.923908        0.333333           0.710000            0.445192
# 11          0.921305        0.250000           1.000000            0.558739
# 12          0.897871        0.500000           0.734524            0.513046
# 13          0.928830        0.000000           0.000000            0.183564
# 14          0.842236        0.750000           1.000000            0.746476
# 15          0.960784        1.000000           0.833333            0.583676
# 16          0.960172        1.000000           0.500000            0.798449
# 17          1.000000        1.000000           0.666667            0.784991
# 18          0.990558        1.000000           0.200000            0.203100
# 19          0.864320        1.000000           1.000000            0.573031

# %% [markdown]
# ## Task 3: Evaluating our Adjusted Pipeline Against Our Baseline
#
# Now we can compare our results and see what directional changes occured!
#
# Let's refresh with our initial metrics.

# %%
results
# Out:
# {'faithfulness': 0.6255, 'answer_relevancy': 0.8526, 'context_recall': 0.6500, 'context_precision': 0.7583, 'answer_correctness': 0.5520}

# %% [markdown]
# And see how our advanced retrieval modified our chain!

# %%
advanced_retrieval_results
# Out:
# {'faithfulness': 0.7120, 'answer_relevancy': 0.9455, 'context_recall': 0.7417, 'context_precision': 0.7112, 'answer_correctness': 0.5529}

# %%
import pandas as pd

df_original = pd.DataFrame(list(results.items()), columns=['Metric', 'Baseline'])
df_comparison = pd.DataFrame(list(advanced_retrieval_results.items()), columns=['Metric', 'MultiQueryRetriever with Document Stuffing'])

df_merged = pd.merge(df_original, df_comparison, on='Metric')

df_merged['Delta'] = df_merged['MultiQueryRetriever with Document Stuffing'] - df_merged['Baseline']

df_merged
# Out:
#                Metric  Baseline  MultiQueryRetriever with Document Stuffing  \
# 0        faithfulness  0.625490                                    0.712024
# 1    answer_relevancy  0.852605                                    0.945499
# 2      context_recall  0.650000                                    0.741667
# 3   context_precision  0.758333                                    0.711185
# 4  answer_correctness  0.551982                                    0.552914
#
#       Delta
# 0  0.086534
# 1  0.092894
# 2  0.091667
# 3 -0.047149
# 4  0.000932

# %% [markdown]
# ## Task 4: Testing OpenAI's Claim
#
# Now that we've seen how our retriever can impact the performance of our RAG pipeline - let's see how changing our embedding model impacts performance.

# %% [markdown]
# ####🏗️ Activity #2:
#
# Please provide markdown, or code comments, to explain which each of the following steps are doing!

# %%
new_embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

# %%
vector_store = Qdrant.from_documents(
    documents,
    new_embeddings,
    location=":memory:",
    collection_name="PMarca Blogs - TE3 - MQR",
)

# %%
new_retriever = vector_store.as_retriever()

# %%
new_advanced_retriever = MultiQueryRetriever.from_llm(retriever=new_retriever, llm=primary_qa_llm)

# %%
new_retrieval_chain = create_retrieval_chain(new_advanced_retriever, document_chain)

# %%
answers = []
contexts = []

for question in test_questions:
  response = new_retrieval_chain.invoke({"input" : question})
  answers.append(response["answer"])
  contexts.append([context.page_content for context in response["context"]])

# %%
new_response_dataset_advanced_retrieval = Dataset.from_dict({
    "question" : test_questions,
    "answer" : answers,
    "contexts" : contexts,
    "ground_truth" : test_groundtruths
})

# %%
new_advanced_retrieval_results = evaluate(new_response_dataset_advanced_retrieval, metrics)
# Out:
# Evaluating:   0%|          | 0/100 [00:00<?, ?it/s]

# %%
new_advanced_retrieval_results
# Out:
# {'faithfulness': 0.8658, 'answer_relevancy': 0.9454, 'context_recall': 0.6792, 'context_precision': 0.8472, 'answer_correctness': 0.5055}

# %%
df_baseline = pd.DataFrame(list(results.items()), columns=['Metric', 'ADA + Baseline'])
df_original = pd.DataFrame(list(advanced_retrieval_results.items()), columns=['Metric', 'ADA + MQR'])
df_comparison = pd.DataFrame(list(new_advanced_retrieval_results.items()), columns=['Metric', 'TE3 + MQR'])

df_merged = pd.merge(df_original, df_comparison, on='Metric')
df_merged = pd.merge(df_baseline, df_merged, on="Metric")

df_merged['ADA + MQR -> TE3 + MQR'] = df_merged['TE3 + MQR'] - df_merged['ADA + MQR']
df_merged['Baseline -> TE3 + MQR'] = df_merged['TE3 + MQR'] - df_merged['ADA + Baseline']

df_merged
# Out:
#                Metric  ADA + Baseline  ADA + MQR  TE3 + MQR  \
# 0        faithfulness        0.625490   0.712024   0.865833
# 1    answer_relevancy        0.852605   0.945499   0.945435
# 2      context_recall        0.650000   0.741667   0.679167
# 3   context_precision        0.758333   0.711185   0.847174
# 4  answer_correctness        0.551982   0.552914   0.505525
#
#    ADA + MQR -> TE3 + MQR  Baseline -> TE3 + MQR
# 0                0.153810               0.240343
# 1               -0.000064               0.092831
# 2               -0.062500               0.029167
# 3                0.135990               0.088841
# 4               -0.047388              -0.046457

# %% [markdown]
# ####❓ Question #4:
#
# Do you think, in your opinion, `text-embedding-3-small` is significantly better than `ada`?

# %% [markdown]
# ## BONUS ACTIVITY: Using a Better Generator
#
# Now that we've seen how much more effective a better Retrieval pipeline is, let's look at what impact a better(?) Generator is!
#
# Adapt the above `TE3 + MQR` pipeline to use `GPT-4o` and compare the results below!

# %%
### YOUR CODE HERE
